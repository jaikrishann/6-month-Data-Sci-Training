# %%
##pandas -- data analysis and manipulation
##excel - sorting , filtering , searching, formulas 
##large data files 
# data preprocessing -- ml models -- raw data -- clean data
# pip install pandas --- third party 
#pip -- package manager 

#csv - comma separated values

# %%
import numpy as np 
import pandas as pd

# %%
##to load the file 
df = pd.read_csv("Used_Bikes.csv")
# df = pd.read_csv(r"D:\6-month-Data-Sci-Training\divya\LIB\Used_Bikes.csv")
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
#dataframe - 2d array -- row and col 
#series - 1d array

# %%
##how to make dataframe on your own 
#dt -- key : value pairs 
dt = {
    "name" : ["a","b","c"],
    "marks" : [10,20,30],
    "city" : ["mumbai","pune","banglore"]
}

df1 = pd.DataFrame(dt)
df1
# Out:
#   name  marks      city
# 0    a     10    mumbai
# 1    b     20      pune
# 2    c     30  banglore

# %%
arr = np.arange(30).reshape(5,6)
arr
df2= pd.DataFrame(arr,columns=["a","b","c","d","e","f"])
df2
# Out:
#     a   b   c   d   e   f
# 0   0   1   2   3   4   5
# 1   6   7   8   9  10  11
# 2  12  13  14  15  16  17
# 3  18  19  20  21  22  23
# 4  24  25  26  27  28  29

# %%
# df.dtypes
# df["price"].dtype
type(df["price"])
#object -- mix of strings and numbers
# Out:
# pandas.core.series.Series

# %%
##accessing a particular column 
df["bike_name"]
df.bike_name

##accessing miultiple columns 
df[["bike_name","price"]]
df[["bike_name","price","kms_driven"]]
# Out:
#                                   bike_name     price  kms_driven
# 0        TVS Star City Plus Dual Tone 110cc   35000.0     17654.0
# 1               Royal Enfield Classic 350cc  119900.0     11000.0
# 2                      Triumph Daytona 675R  600000.0       110.0
# 3                      TVS Apache RTR 180cc   65000.0     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0     10000.0
# ...                                     ...       ...         ...
# 32643                Hero Passion Pro 100cc   39000.0     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0      6639.0
# 32645              Bajaj Avenger Street 220   60000.0     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0     60857.0
#
# [32648 rows x 3 columns]

# %%
##row access
df[0:10]
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
##types of accessing 

##loc - label based indexing -- naam se 
##iloc - integer based indexing -- index number

# %%
##2d array -- [row,col]
# df.iloc[]

##loc 
df.loc[1:10,["bike_name","price","city"]]
# Out:
#                                    bike_name     price       city
# 1                Royal Enfield Classic 350cc  119900.0      Delhi
# 2                       Triumph Daytona 675R  600000.0      Delhi
# 3                       TVS Apache RTR 180cc   65000.0  Bangalore
# 4       Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore
# 5                           Yamaha FZs 150cc   53499.0      Delhi
# 6              Honda CB Hornet 160R  ABS DLX   85000.0      Delhi
# 7        Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi
# 8          Royal Enfield Thunderbird X 350cc  145000.0  Bangalore
# 9   Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi
# 10                  Yamaha YZF-R15 2.0 150cc   72000.0  Bangalore

# %%
##basic operation -- max , min 
df.max()
df["price"].max()
df["price"].min()
df["price"].mean()
df["price"].sum()
df["price"].median()
df["price"].std()
df["price"].var()
# Out:
# np.float64(8229863516.012512)

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df["city"].unique()
df["city"].nunique()
df["city"].value_counts()
# Out:
# city
# Delhi         7318
# Bangalore     2723
# Mumbai        2591
# Hyderabad     2160
# Pune          1724
#               ...
# Berhampore       1
# Silvasa          1
# Hospet           1
# Palai            1
# Sidhi            1
# Name: count, Length: 443, dtype: int64

# %%
df.head()
df.tail(20)
# Out:
#                              bike_name     price                 city  \
# 32628         Bajaj Avenger Street 220   80000.0            Hyderabad
# 32629              Bajaj Platina 100cc   23000.0              Lucknow
# 32630      Suzuki Slingshot Plus 125cc   32000.0              Lucknow
# 32631               Yamaha SZ-RR 150cc   20000.0          Kanchipuram
# 32632         Bajaj Avenger Street 220   55005.0              Godhara
# 32633      Royal Enfield Classic 350cc   87000.0  Gautam Buddha Nagar
# 32634  Royal Enfield Thunderbird 350cc   70000.0               Mumbai
# 32635                Suzuki Zeus 125cc   35000.0            Ahmedabad
# 32636                     KTM RC 390cc  196700.0               Mumbai
# 32637               Bajaj Pulsar 150cc   25000.0                Delhi
# 32638            Yamaha Fazer 25 250cc  123000.0               Kadapa
# 32639      Royal Enfield Classic 350cc   95500.0                Delhi
# ...

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
##filteringg
##problem statement ----df--city -- delhi // size -- m 
## = --> value assign 
## == --> condition check//comparison 
delhi = df[df["city"] == "Delhi"]

##owner -- values?
delhi[delhi["owner"] == 'Fourth Owner Or More']
#data ko filter karn              owner -- 4 owner
# Out:
#                                bike_name    price   city  kms_driven  \
# 2999     Royal Enfield Thunderbird 350cc  95000.0  Delhi      9392.0
# 7038  Royal Enfield Bullet Electra 350cc  35000.0  Delhi     60000.0
#
#                      owner   age  power          brand
# 2999  Fourth Owner Or More   6.0  350.0  Royal Enfield
# 7038  Fourth Owner Or More  18.0  350.0  Royal Enfield

# %%
##wo bikess fetch jiski price kya ho 60k se jyda ya barabaar ho

# %%
delhi[delhi["price"] >= 60000]
# Out:
#                                       bike_name     price   city  kms_driven  \
# 1                   Royal Enfield Classic 350cc  119900.0  Delhi     11000.0
# 2                          Triumph Daytona 675R  600000.0  Delhi       110.0
# 6                 Honda CB Hornet 160R  ABS DLX   85000.0  Delhi      8200.0
# 9      Royal Enfield Classic Desert Storm 500cc   88000.0  Delhi     19000.0
# 44                  Royal Enfield Classic 350cc   85000.0  Delhi     18000.0
# ...                                         ...       ...    ...         ...
# 32601               Royal Enfield Classic 350cc   95500.0  Delhi     18000.0
# 32607                  Bajaj Avenger Street 220   60000.0  Delhi     20373.0
# 32614        Royal Enfield Bullet Electra 350cc  105000.0  Delhi     20000.0
# 32639               Royal Enfield Classic 350cc   95500.0  Delhi     18000.0
# 32645                  Bajaj Avenger Street 220   60000.0  Delhi     20373.0
#
# ...

# %%
##multiple conditons 
## probelm statement - brand -- tvs , age <= 3, power <= 110 
df[(df["brand"] == "TVS") &  (df["age"] <= 3) &  (df["power"] <= 110)]

##brand --ktm , kms driven less than ya equal too 5000 , price less than 50000
# Out:
#                                bike_name    price         city  kms_driven  \
# 0     TVS Star City Plus Dual Tone 110cc  35000.0    Ahmedabad     17654.0
# 986                      TVS Sport 100cc  34000.0        Delhi      8048.0
# 1084                     TVS Sport 100cc  34000.0        Delhi      8048.0
# 2360           TVS Victor 110cc Disc SBT  54000.0        Delhi      6000.0
# 2381           TVS Victor 110cc Disc SBT  54000.0        Delhi      6000.0
# 2494                     TVS Sport 100cc  39900.0    Bangalore     15000.0
# 2710                    TVS Victor 110cc  40000.0      Chennai     12530.0
# 3362                     TVS Sport 100cc  32000.0    Faridabad     15820.0
# 4114           TVS Radeon 110cc Drum SBT  38000.0        Delhi     21249.0
# 4251            TVS Star City Plus 110cc  51000.0    Ahmedabad     12000.0
# 5468                     TVS Sport 100cc  38000.0        Noida      8718.0
# ...

# %%
## data preprocessing --data cleaning
#1 -- null values delete ya transform 
#2 -- duplicate values delete 
#3 -- outlier values delete --- seaborn

# %%
##null values -- nan -- not a number
##check null values
df.isnull().sum()
##remove null values
df.dropna(inplace=True)

#transform 
##constant  - 0 , 1 
## mean , median , mode
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
#to check duplicate values
df.duplicated().sum()
## to remove duplicate 
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
## to save a file 
df.to_csv("cleaned_csv.csv")

# %%
df.sort_values("price") ##default -- ascending order 
df.sort_values("price",ascending=False)

##sort index 
df.sort_index()
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
#dict 
dt = {
    "a" : [1,2,3,4],
    "b" : [5,np.nan,7,np.nan],
    "c" : [np.nan,9,np.nan,11]
}

df1 = pd.DataFrame(dt)
df1
# Out:
#    a    b     c
# 0  1  5.0   NaN
# 1  2  NaN   9.0
# 2  3  7.0   NaN
# 3  4  NaN  11.0

# %%
df1.isnull().sum()
# df1.dropna() ##default me rows delete 
# axis = 1 -- columns
# axis --0 -- row 
df1.dropna(axis=1)
# Out:
#    a
# 0  1
# 1  2
# 2  3
# 3  4

# %%
#tranform -- constant , mean , median , mode 
df1.fillna(0)      #constant 
df1.fillna(df1.mean())
df1.fillna(df1.median())
df1.fillna(df1.mode()) ##most freq value
# Out:
#    a    b     c
# 0  1  5.0   9.0
# 1  2  7.0   9.0
# 2  3  7.0   NaN
# 3  4  NaN  11.0

# %%
##column operations -- 
df.head()
df["price"]=df["price"] + 5000
df["inc_price"]=df["price"] + 5000
df["new"] = df["price"] * df["age"]

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   50000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  134900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  615000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   80000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   95000.0  Bangalore     10000.0
#
#          owner  age  power          brand  inc_price        new
# 0  First Owner  3.0  110.0            TVS    55000.0   150000.0
# 1  First Owner  4.0  350.0  Royal Enfield   139900.0   539600.0
# 2  First Owner  8.0  675.0        Triumph   620000.0  4920000.0
# 3  First Owner  4.0  180.0            TVS    85000.0   320000.0
# 4  First Owner  3.0  150.0         Yamaha   100000.0   285000.0

# %%
##delete column
# df.drop("inc_price",axis=1)
df.drop(["inc_price","new"],axis=1)
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   50000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  134900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  615000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   80000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   95000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   40000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   50000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  465000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  154000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   95000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.rename(columns={"price":"new_price"},inplace=True)

# %%
df.head()
# Out:
#                               bike_name  new_price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc    50000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc   134900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R   615000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc    80000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition    95000.0  Bangalore     10000.0
#
#          owner  age  power          brand  inc_price        new
# 0  First Owner  3.0  110.0            TVS    55000.0   150000.0
# 1  First Owner  4.0  350.0  Royal Enfield   139900.0   539600.0
# 2  First Owner  8.0  675.0        Triumph   620000.0  4920000.0
# 3  First Owner  4.0  180.0            TVS    85000.0   320000.0
# 4  First Owner  3.0  150.0         Yamaha   100000.0   285000.0

# %%
##group by 
##filtering -- city -- delhi 
# df[df["city"] == "Delhi"]
owner_grp = df.groupby("city")
owner_grp.get_group("Delhi")
# Out:
#                                  bike_name  new_price   city  kms_driven  \
# 1              Royal Enfield Classic 350cc   134900.0  Delhi     11000.0
# 2                     Triumph Daytona 675R   615000.0  Delhi       110.0
# 5                         Yamaha FZs 150cc    68499.0  Delhi     25000.0
# 6            Honda CB Hornet 160R  ABS DLX   100000.0  Delhi      8200.0
# 7      Hero Splendor Plus Self Alloy 100cc    60000.0  Delhi     12645.0
# ...                                    ...        ...    ...         ...
# 9336                   Yamaha YZF-R3 320cc   235000.0  Delhi      7130.0
# 9338         Royal Enfield Himalayan 410cc   153000.0  Delhi      5000.0
# 9340                Honda CB Trigger 150cc    49400.0  Delhi     24513.0
# 9344  Royal Enfield Bullet Twinspark 350cc    95000.0  Delhi     56968.0
# 9362             Hero Hunk Rear Disc 150cc    40000.0  Delhi     48587.0
#
#              owner  age  power          brand  inc_price        new
# ...

# %%
##aggregate -- 
owner_grp["age"].agg(max_age = "max", min_age = "min", avg_age = "mean",
                    sum_age = "sum"
                    ,nunique_age = "nunique")
# Out:
#               max_age  min_age   avg_age  sum_age  nunique_age
# city
# 24 Pargana        8.0      2.0  5.100000     51.0            7
# Abohar            8.0      8.0  8.000000      8.0            1
# Adalaj           14.0      4.0  8.400000     42.0            5
# Adoni             4.0      4.0  4.000000      4.0            1
# Adyar            10.0      6.0  8.000000     16.0            2
# ...               ...      ...       ...      ...          ...
# Warangal          7.0      6.0  6.500000     13.0            2
# Wardha            8.0      3.0  5.333333     16.0            3
# Yamuna Nagar     11.0      4.0  7.500000     15.0            2
# Yemmiganur        9.0      9.0  9.000000      9.0            1
# Zirakpur          4.0      4.0  4.000000      4.0            1
#
# [443 rows x 5 columns]
